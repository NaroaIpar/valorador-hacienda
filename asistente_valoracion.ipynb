# %% [markdown]
# # Ejecuta esta celda para descargar dependencias

# %%
# 1. Instalar las librerías de tu requirements
# !pip install -r requirements.txt

# 2. EL PASO MÁGICO DE PLAYWRIGHT (Sin esto, fallará)
# Esto descarga los navegadores internos que usa Playwright
# !playwright install chromium

# %% [markdown]
# # Ejecuta esta celda si el "Inicial_Valorador.bat" no funciona

# %%
# !streamlit run app.py
